# %%
# Example script to calculate and plot the hyperfine / Zeeman levels of T and H
import sys
sys.path.append("../src/")
sys.path.append("../src/AtomicH")

# %%
import numpy as np
import pylab as plt
import potentials
import constants

# %%
R=np.linspace(1e-5,0.005,100)
plt.figure(figsize=(5,5),dpi=150)
plt.plot(R*constants.hcInEVAngstrom,potentials.Silvera_Triplet(R),label='Silvera Triplet')
plt.plot(R*constants.hcInEVAngstrom,potentials.Silvera_Singlet(R),label='Silvera Singlet')
plt.legend(loc='upper right')
plt.ylim(-10,10)
plt.xlabel(r"R ($\AA$)")
plt.ylabel("V (eV)")
# Out:
# Text(0, 0.5, 'V (eV)')

# %%
Pots=[potentials.Silvera_Triplet,potentials.Silvera_Triplet2, potentials.UnCorrectedSilvera_Triplet]
Names=['Silvera 1','Silvera 2','Un-Adiabatic Corrected Silvera']
R=np.linspace(0,0.01,100)
plt.figure(figsize=(5,5),dpi=150)
for i in range(0,len(Pots)):
    plt.plot(R*constants.hcInEVAngstrom, Pots[i](R)/Pots[0](R),label=Names[i])
plt.ylim(0.7,1.1)
plt.xlabel(r"R ($\AA$)")
plt.ylabel("Ratio")
plt.legend(loc='upper right')
# Out:
# /Users/benjpjones/PycharmProjects/AtomicHScattering/examples/../src/AtomicH/potentials.py:14: RuntimeWarning: divide by zero encountered in divide
#   F=(R>D)+(R<D)*np.exp(-(D/R-1)**2)
# /Users/benjpjones/PycharmProjects/AtomicHScattering/examples/../src/AtomicH/potentials.py:15: RuntimeWarning: divide by zero encountered in divide
#   return 6.46 * K2eV * (4.889e4*np.exp(0.0968-8.6403*R-2.427*R**2)-(1.365/R**6+0.425/R**8+0.183/R**10)*F)
# /Users/benjpjones/PycharmProjects/AtomicHScattering/examples/../src/AtomicH/potentials.py:15: RuntimeWarning: invalid value encountered in multiply
#   return 6.46 * K2eV * (4.889e4*np.exp(0.0968-8.6403*R-2.427*R**2)-(1.365/R**6+0.425/R**8+0.183/R**10)*F)
# /Users/benjpjones/PycharmProjects/AtomicHScattering/examples/../src/AtomicH/potentials.py:19: RuntimeWarning: divide by zero encountered in divide
#   P = np.exp(0.09678-1.10173*R-0.03945*R**2)+np.exp(-(10.04/R-1)**2)*(-6.5/R**6-124/R**8-3285/R**10)
# /Users/benjpjones/PycharmProjects/AtomicHScattering/examples/../src/AtomicH/potentials.py:19: RuntimeWarning: invalid value encountered in multiply
#   P = np.exp(0.09678-1.10173*R-0.03945*R**2)+np.exp(-(10.04/R-1)**2)*(-6.5/R**6-124/R**8-3285/R**10)

# %%
Pots = [ potentials.Kolos_SingletCombo,potentials.Kolos_Singlet1, potentials.Kolos_Singlet2,potentials.Silvera_Singlet]
Names = ['Kolos Combo', 'Kolos 1', 'Kolos 2','Silvera Singlet']
linetype=['-',':','--','-.']
R = np.linspace(0, 0.005, 100)+1e-5
plt.figure(figsize=(5, 5), dpi=150)
for i in range(0, len(Pots)):
    plt.plot(R * constants.hcInEVAngstrom, Pots[i](R),linetype[i], label=Names[i],alpha=0.5)
plt.xlim(0,5)
plt.ylim(-6,6)
plt.xlabel(r"R ($\AA$)")
plt.ylabel("Ratio")
plt.legend(loc='upper right')
